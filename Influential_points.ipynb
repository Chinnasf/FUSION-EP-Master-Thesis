# %% [markdown]
# ### Not the same as the optimization problem

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit
from sklearn.linear_model import LinearRegression

# %%
o = pd.read_csv("data/O.csv") # logarithmic data 
r = pd.read_csv("data/R.csv") # logarithmic data 


data = pd.concat([o, r], ignore_index=True)

## Removing the spherical TOKAMAKS
data = data[~data.TOK.isin(['MAST', 'NSTX'])]


y = data[["TAUTH"]]
X = data[data.columns[1:9]]

# %%
data
# Out:
#          TAUTH        IP        BT       NEL      PLTH      RGEO     KAREA  \
# 0    -2.975930 -1.217734  0.790728  1.332102  0.625938  0.527093 -0.025523
# 1    -3.015527 -1.220102  0.790728  1.317480  0.705076  0.521172 -0.027988
# 2    -2.752786 -1.213686  0.790728  1.226712  0.123986  0.526502 -0.010556
# 3    -2.660547 -1.217734  0.790728  1.328400  0.319181  0.526502 -0.025933
# 4    -2.965979 -1.223495  0.790274  1.347294  0.709513  0.521766 -0.031387
# ...        ...       ...       ...       ...       ...       ...       ...
# 6245 -1.371545  1.092136  1.041495  1.932164  3.486544  1.063790  0.427590
# 6246 -1.261046  1.243396  1.129817  2.277883  3.367778  1.062715  0.429045
# 6247 -1.337700  0.729835  0.705899  1.842903  2.461911  1.054231  0.436725
# 6248 -1.303244  1.243548  1.130438  2.295214  3.472664  1.061939  0.426412
# 6249 -1.681568  0.678881  0.881083  1.681912  2.543876  1.066668  0.432865
#
#            EPS      MEFF     TOK   SHOT      DATE    TIME    ind
# ...
