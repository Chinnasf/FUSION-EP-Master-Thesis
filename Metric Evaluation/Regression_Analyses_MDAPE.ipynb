# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import statsmodels.api as sm
import seaborn as sns

sstyle = "seaborn-poster"
plt.style.use(sstyle)
plt.rc('font',family = 'serif')

np.random.seed(71)

coeffs = ['IP', 'BT', 'NEL', 'PLTH', 'RGEO', 'KAREA', 'EPS', 'MEFF']
# Out:
# /tmp/ipykernel_13229/1618576811.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(sstyle)

# %%
R = pd.read_csv("../data/R.csv")

DB5P1 = pd.read_csv("../data/DB5.csv")
DB2P8 = pd.read_csv("../data/DB2P8.csv")

DB5 = DB5P1[["TAUTH"] + coeffs].apply(np.abs).apply(np.log)
DB5["id"] = DB5P1["id"]

DB2 = DB2P8[["TAUTH"] + coeffs].apply(np.abs).apply(np.log)
DB2["id"] = DB2P8["id"]

data = DB5.copy()

# %%
def compute_OLS_regression(data):
    # Adding a column for the intercept
    _df = data[coeffs]; _df.insert(
        loc = 0, 
        column = "intercept", 
        value = np.ones(len(_df))
    )
    X = _df.to_numpy()
    Y = data[["TAUTH"]].to_numpy()
    model = sm.OLS(Y,X)
    regression = model.fit()
    return regression
    
regression = compute_OLS_regression(data)
regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                 1.250e+04
# Date:                Wed, 22 Feb 2023   Prob (F-statistic):               0.00
# Time:                        13:04:11   Log-Likelihood:                 1140.9
# No. Observations:                6250   AIC:                            -2264.
# Df Residuals:                    6241   BIC:                            -2203.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.5185      0.029    -88.236      0.000      -2.574      -2.463
# x1             1.1343      0.016     69.337      0.000       1.102       1.166
# x2             0.0724      0.014      5.076      0.000       0.044       0.100
# x3             0.1749      0.010     18.246      0.000       0.156       0.194
# x4            -0.6827      0.007   -100.092      0.000      -0.696      -0.669
# x5             1.4480      0.026     56.745      0.000       1.398       1.498
# x6             0.2802      0.029      9.726      0.000       0.224       0.337
# x7             0.0636      0.037      1.721      0.085      -0.009       0.136
# x8             0.2140      0.017     12.538      0.000       0.181       0.247
# ==============================================================================
# Omnibus:                      103.850   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.017
# Skew:                          -0.148   Prob(JB):                     1.21e-37
# Kurtosis:                       3.752   Cond. No.                         64.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Multiplication Factor 
γ = 100
# Re-scal=ed Covariance Matrix
COVM = pd.DataFrame(γ * regression.cov_params(), 
                    columns= ["intercept"] + coeffs, 
                    index  = ["intercept"] + coeffs
                   )
COVM
# Out:
#            intercept        IP        BT       NEL      PLTH      RGEO  \
# intercept   0.081470 -0.006213  0.017640 -0.004058 -0.004046  0.009079
# IP         -0.006213  0.026763 -0.016536 -0.005552  0.000189 -0.034605
# BT          0.017640 -0.016536  0.020326  0.000742 -0.002162  0.019989
# NEL        -0.004058 -0.005552  0.000742  0.009191 -0.002711  0.015865
# PLTH       -0.004046  0.000189 -0.002162 -0.002711  0.004652 -0.007419
# RGEO        0.009079 -0.034605  0.019989  0.015865 -0.007419  0.065112
# KAREA      -0.011518 -0.025154  0.023099  0.001103 -0.005033  0.031308
# EPS         0.058950 -0.050333  0.041455  0.014157 -0.007224  0.077594
# MEFF       -0.018026 -0.000457 -0.004041 -0.002343  0.000873 -0.000990
#
#               KAREA       EPS      MEFF
# intercept -0.011518  0.058950 -0.018026
# IP        -0.025154 -0.050333 -0.000457
# BT         0.023099  0.041455 -0.004041
# NEL        0.001103  0.014157 -0.002343
# PLTH      -0.005033 -0.007224  0.000873
# RGEO       0.031308  0.077594 -0.000990
# KAREA      0.082974  0.039296 -0.007695
# EPS        0.039296  0.136531 -0.007435
# MEFF      -0.007695 -0.007435  0.029133

# %%
MEAN = pd.DataFrame(regression.params).T; MEAN.columns = columns = ["intercept"] + coeffs
MEAN
# Out:
#    intercept       IP        BT       NEL     PLTH      RGEO     KAREA  \
# 0  -2.518511  1.13432  0.072368  0.174924 -0.68271  1.447975  0.280173
#
#         EPS      MEFF
# 0  0.063607  0.214009

# %%
N = 20 #4000
def get_rand_sample(μ, σ, N):
    s = np.random.normal(μ, σ, N)
    return s


def get_rand_multivariate(Μ, Σ, N):
    s = np.random.multivariate_normal(Μ, Σ, N)
    return s

# %%
(γ * regression.cov_params()).shape
# Out:
# (9, 9)

# %%
PARAM_SAMPLING = pd.DataFrame(get_rand_multivariate(regression.params, γ * regression.cov_params(), N),
                             columns=["intercept"]+coeffs)
PARAM_SAMPLING
# Out:
#     intercept        IP        BT       NEL      PLTH      RGEO     KAREA  \
# 0   -2.126365  1.068932  0.161214  0.076242 -0.668101  1.422909  0.169542
# 1   -2.508614  0.958330  0.238164  0.313381 -0.675904  1.733050  0.072349
# 2   -2.322964  1.327652 -0.098299  0.089611 -0.616007  1.043520 -0.151378
# 3   -2.642387  0.866762  0.258272  0.144155 -0.624169  1.754900  0.503733
# 4   -2.841522  0.935052  0.058846  0.189889 -0.670377  1.675226  0.516407
# 5   -2.165323  0.983648  0.310108  0.202201 -0.717372  1.651566  0.457913
# 6   -2.693067  1.241759  0.060168  0.165880 -0.741227  1.361423  0.562241
# 7   -2.697684  1.190844 -0.079656  0.133848 -0.606432  1.291909 -0.110846
# 8   -2.582901  1.159966  0.057569  0.024843 -0.705325  1.454224  0.324044
# 9   -2.361130  1.108226  0.096941  0.166302 -0.755322  1.538971  0.349454
# 10  -2.594433  1.326734 -0.087735  0.095970 -0.709591  1.232337  0.147356
# 11  -2.679876  0.698068  0.251172  0.313827 -0.601962  1.889297  0.680474
# 12  -2.189713  0.916185  0.204780  0.296194 -0.786034  1.821743  0.660316
# 13  -2.519326  0.972441  0.152315  0.245290 -0.636243  1.636204  0.060740
# 14  -2.771605  1.343696 -0.200170  0.283349 -0.708321  1.352479 -0.172644
# 15  -2.593411  1.191634  0.082277  0.043696 -0.481913  1.010623 -0.239513
# 16  -2.645388  1.020885  0.207222 -0.078750 -0.618173  1.344435  0.840772
# 17  -2.227145  0.830038  0.312388  0.295842 -0.782652  2.001814  0.460707
# 18  -2.395433  1.254118  0.051994  0.188752 -0.732734  1.351003  0.244668
# 19  -2.286318  0.977370  0.149333  0.314307 -0.701559  1.785778  0.129233
#
#          EPS      MEFF
# 0   0.228755  0.155884
# 1   0.451028  0.176323
# 2  -0.276409  0.203358
# 3   0.497073  0.386779
# 4   0.159335  0.505527
# 5   0.620920  0.165214
# 6  -0.178927  0.106061
# 7  -0.264557  0.389025
# 8  -0.092750  0.483967
# 9   0.236296  0.318327
# 10 -0.432593  0.188183
# 11  0.649838  0.078836
# 12  0.798724  0.196599
# 13  0.374551  0.340619
# 14 -0.410300  0.199649
# 15 -0.128674  0.578743
# 16 -0.061611  0.286781
# 17  0.962563  0.407380
# 18 -0.043340  0.003851
# 19  0.558363  0.114758

# %%
# Adding first row to be the estimated values from OLS for comparison
PARAM_SAMPLING = pd.concat([MEAN, PARAM_SAMPLING],
                     axis=0, 
                     ignore_index=True
                    )

# %%
def get_hat_τ(X, parameters):
    I, B, n_e, P, R, κ, ε, M_eff = X 
    α0, αI, αB, αn, αP, αR, ακ, αε, αM_eff = parameters
    hat_τ = α0 + αI*I + αB*B + αn*n_e + αP*P + αR*R + ακ*κ + αε*ε + αM_eff*M_eff 
    return hat_τ

# %%
data_ = DB5.copy()
data_
# Out:
#          TAUTH        IP        BT       NEL      PLTH      RGEO     KAREA  \
# 0    -2.975930 -1.217734  0.790728  1.332102  0.625938  0.527093 -0.025523
# 1    -3.015527 -1.220102  0.790728  1.317480  0.705076  0.521172 -0.027988
# 2    -2.752786 -1.213686  0.790728  1.226712  0.123986  0.526502 -0.010556
# 3    -2.660547 -1.217734  0.790728  1.328400  0.319181  0.526502 -0.025933
# 4    -2.965979 -1.223495  0.790274  1.347294  0.709513  0.521766 -0.031387
# ...        ...       ...       ...       ...       ...       ...       ...
# 6245 -4.094745 -1.515037  0.674474  1.593105 -0.486946 -0.189467  0.102557
# 6246 -4.068677 -1.514582  0.668854  1.631004 -0.452871 -0.179605  0.096219
# 6247 -3.671826 -1.515037  0.668342  1.674664 -0.977634 -0.180324  0.098034
# 6248 -1.753886 -0.020815  1.567574  1.252763  1.631591  0.897719 -0.000300
# 6249 -1.703749 -0.028399  1.566739  1.231393  1.608037  0.898534 -0.001601
#
#            EPS      MEFF      id
# 0    -1.418447  0.405465  HDULEH
# 1    -1.409604  0.405465  NAC6N1
# 2    -1.432100  0.405465  U2T1C7
# 3    -1.417369  0.405465  422XQB
# 4    -1.406800  0.405465  WZ9FED
# ...        ...       ...     ...
# 6245 -1.347185  0.693147  NGC85H
# 6246 -1.354725  0.693147  ID1IP4
# 6247 -1.355399  0.693147  K19A5H
# 6248 -1.116746  0.693147  D26CA1
# 6249 -1.115199  0.693147  UPV67I
#
# [6250 rows x 10 columns]

# %%
for p in range(len(PARAM_SAMPLING)):
    data_[f"τ_{p}"] = np.zeros(len(DB5))
    for observation in range(len(DB5)):
        data_.iloc[observation, len(data_.columns) - 1] = get_hat_τ(
            data_.loc[observation].loc[coeffs].values,
            PARAM_SAMPLING.loc[p].values
        )

# %%
params = ["intercept"] + coeffs

# %%
hat_τ = data_[data_.columns[len(params) + 1:]]
residuals = hat_τ.sub( data_["TAUTH"], axis=0 )
abs_relative_residual = (residuals.div( data_["TAUTH"], axis=0 )).apply( np.abs )

# %%
MDAPE = abs_relative_residual.median(axis=0)
MDAPE
# Out:
# τ_0     0.068998
# τ_1     0.072325
# τ_2     0.072219
# τ_3     0.067907
# τ_4     0.075333
# τ_5     0.071385
# τ_6     0.074809
# τ_7     0.071560
# τ_8     0.067096
# τ_9     0.071928
# τ_10    0.070094
# τ_11    0.069386
# τ_12    0.077954
# τ_13    0.074898
# τ_14    0.069460
# τ_15    0.067339
# τ_16    0.077773
# τ_17    0.077029
# τ_18    0.075416
# τ_19    0.072020
# τ_20    0.071045
# dtype: float64

# %%
fig = plt.figure(figsize=(12,6))
ax = plt.gca()

labels = ["τ_OLS"] + list(MDAPE.index[1:])

for i,τ in enumerate(MDAPE.index[2:]):
    plt.scatter(data_["TAUTH"].apply(np.exp), data_[τ].apply(np.exp), s=4, color="tan")

plt.scatter(data_["TAUTH"].apply(np.exp), data_["τ_0"].apply(np.exp),
            s=4, label = "Sampled from MND", color="tan")
plt.scatter(data_["TAUTH"].apply(np.exp), data_["τ_0"].apply(np.exp),
            s=4, label = "OLS", color="firebrick")

plt.xlabel("Predicted Confinement Time $\\:\\hat{\\tau}$ [s]", fontsize=16)
plt.ylabel("Measured Confinement Time $\\:\\tau$ [s]", fontsize=16)

ax.set_yscale('log')
ax.set_xscale('log')

plt.grid(alpha=0.25,linestyle='dashed', which="both")
ax.set_axisbelow(True)

plt.legend(markerscale=4)

fig.tight_layout()

#plt.savefig('MND_OLS_20_samples.png', format="png", dpi=300)
